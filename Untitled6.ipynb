# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
Name = {"Aanuoluwapo":45, "Abidoye":67, "Samuel":77, "Holuwagbotemi":27, "Hanuoluwapo":88}

y_name = Name.keys()
x_name = Name.values()

y_names = np.arange(len(Name))

plt.bar(y_name,y_names, alpha=0.5)
plt.xticks(y_names,y_name)
plt.ylabel(x_name)
plt.title("the name of the lord shall be glorified")
plt.show()

# %%
Team = {"Manchester_united":56, "chelsea":78, "Aresenal":78, "Manchester_city":79}
Team_united = Team.keys()
Team_unites = Team.values()

Team_united_unites = np.arange(len(Team))
plt.bar(Team_united_unites, Team_united, alpha =0.5)
plt.xticks(Team_united_unites, Team_united)
plt.ylabel(Team_unites)
plt.title("The name of this teams is super talented")
plt.show()

# %%
classes = {"primary_school":23, "secondary_school":45, "tertiary_school":77, "pre-degree":50, "jupeb":72}
class_total = classes.keys()
classes_total = classes.values()
classes_total_number = np.arange(len(classes))

plt.bar(classes_total_number, classes_total, alpha=0.7)
plt.xticks(classes_total_number, class_total)
plt.ylabel(class_total)
plt.title("the name of the arranged alphabetical order of classes")
plt.show()

# %%
practical = {"chemistry": 77, "physics": 76, "biology": 78, "pharmacology":75, "pathology": 77}
total_practical = practical.keys()
total_practicals = practical.values()

new_total_practical = np.arange(len(practical))

plt.bar(new_total_practical, total_practicals, alpha=0.7)
plt.xticks(new_total_practical,total_practical)
plt.ylabel(total_practicals)
plt.title("the names of the title we normal do in the class")
plt.show()

# %%
## Pie chart

# %%
total_practical = practical.keys()
total_practical = practical.values()
colors = ["Red", "Blue", "Green", "Yellow", "White"]

plt.pie(total_practicals, labels=total_practical, startangle = 170)
plt.axis("equal")
plt.show()

# %%
Hostel = {"Adonai":70, "Ayo-arike":67, "Bver":78, "Mercy of God":79, "Bishop":22}
hostel = Hostel.keys()
Hostels = Hostel.values()

hostels = np.arange(len(Hostel))

plt.bar(hostels, Hostels, alpha=0.7)
plt.xticks(hostels, hostel)
plt.ylabel(Hostels)
plt.title("those are the name of the hostels in cdl")
plt.show()

# %%
speciality = {"cardiology":45, "pathology":21, "neurology":43, "nephrology":34, "Radiology":67}
Speciality = speciality.keys()
specialities = speciality.values()

specialitys = np.arange(len(speciality))
plt.bar(specialitys, specialities, alpha = 1)
plt.xticks(specialitys, Speciality)
plt.ylabel(specialities)
plt.title("the specialities in clinical medicine")
plt.show()

# %%
Speciality = speciality.keys()
specialities = speciality.values()
colors = ["Red", "blue", "green","yellow", "white"]
plt.pie(specialities, labels=specialities, startangle=140)
plt.axis("equal")
plt.show()

# %%
classes = {"Aanuoluwapo":57, "Abidoye":56, "Samuel":70}
x_classes = classes.keys()
y_classes = classes.values()

x_class = np.arange(len(classes))

plt.bar(x_class, y_classes, alpha=0.6)
plt.xticks(x_class, x_classes)
plt.ylabel(y_classes)
plt.title("the name of those classes we are taking this semesters sessions")
plt.show()

# %%
x_classes = classes.keys()
y_classes = classes.values()
colors = ["white", "blue", "green"]
plt.pie(y_classes,labels=x_classes, startangle = 97)
plt.axis("equal")
plt.show()

# %%
colour = {"RED":56, "YELLOW":67, "WHITE":77, "GREEN":89, "BROWN":34, "BLUE":56, "INDIGO":89}
Colors = colour.keys()
colours = colour.values()
color = np.arange(len(colour))
plt.bar(color,colours, alpha=0.7)
plt.xticks(color,Colors)
plt.ylabel(colours)
plt.title("the name of the colour in the machine learnng")
plt.show()

# %%
colors = colour.keys()
colours = colour.values()
colors = ["Red", "yellow", "white", "green", "brown", "blue", "indigo"]
plt.pie(colours, labels=colors, startangle=340)
plt.axis("equal")
plt.show()

# %%
Name_of_school={"obafemi Awolowo university":56, "university_of_ibadan":77, "university_of_benin":45, "university_of_ilorin":34, "university_of_jos":89}
name_of_school=Name_of_School.keys()
Names_of_school=Name_of_school.values()
names_of_schools=np.arange(len(Name_of_school))
plt.bar(names_of_schools,Names_of_school, alpha=0.9)
plt.xticks(names_of_schools,name_of_school)
plt.ylabel(Names_of_school)
plt.title("the name of the schools in the western region")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 Name_of_school={"obafemi Awolowo university":56, "university_of_ibadan":77, "university_of_benin":45, "university_of_ilorin":34, "university_of_jos":89}
# ----> 2 name_of_school=Name_of_School.keys()
#       3 Names_of_school=Name_of_school.values()
#       4 names_of_schools=np.arange(len(Name_of_school))
#
# NameError: name 'Name_of_School' is not defined

# %%
Name_of_school = {"obafemi Awolowo university":57, "university_of_ibadan":77, "university_of_benin":45, "university_of_ilorin":34, "university_of_jos":89}
name_of_school = Name_of_school.keys()
names_of_schools = Name_of_school.values()
names_of_total_schools = np.arange(len(Name_of_school))
plt.bar(names_of_total_schools,names_of_schools,alpha=0.7)
plt.xticks(names_of_total_schools,name_of_school)
plt.ylabel(names_of_schools)
plt.title("the name of the schools in western part of Nigeria")
plt.show()

# %%
name_of_school = Name_of_school.keys()
names_of_schools = Name_of_school.values()
colors = ["Red", "wine","black", "pink", "purple"]
plt.pie(names_of_schools, labels=name_of_school,startangle=300)
plt.axis("equal")
plt.show()

# %%
## metrics Analyses

# %%
import pandas as pd
import numpy as np


species_count = np.random.randint(100, 300, size=100)
print(species_count)
# Out:
# [121 169 129 213 195 163 217 101 230 270 256 184 122 159 147 258 164 173
#  299 268 251 216 214 209 167 283 154 275 299 200 231 275 200 170 266 182
#  131 101 196 191 267 278 147 125 188 225 240 191 287 207 274 169 243 244
#  116 271 209 106 268 241 239 232 203 114 113 166 259 115 143 260 237 145
#  186 153 154 284 114 279 261 145 278 206 154 264 117 286 212 147 180 166
#  107 299 145 106 195 261 102 142 278 243]

# %%
Area = ["area" + str(i) for i in range(1,101)]
Areas = {"area":Area,"Species_count":species_count}
df = pd.DataFrame(Areas)
df
# Out:
#        area  Species_count
# 0     area1            121
# 1     area2            169
# 2     area3            129
# 3     area4            213
# 4     area5            195
# ..      ...            ...
# 95   area96            261
# 96   area97            102
# 97   area98            142
# 98   area99            278
# 99  area100            243
#
# [100 rows x 2 columns]

# %%
population_area = df["Species_count"].mean()

# %%
population_area
# Out:
# 200.35

# %%
population_area = df["area"].sum()

# %%
population_area
# Out:
# '...'

# %%
population_area = df["Species_count"].sum()

# %%
population_area
# Out:
# 20035

# %%
population_area
# Out:
# 20035

# %%
population_area = df["Species_count"].mean()

# %%
population_area
# Out:
# 200.35

# %%
sample = df.head(3)
sample.mean = df["Species_count"].mean()
print("Population_area:",population_area)
print("Sample_mean:", sample.mean)
# Out:
# Population_area: 200.35
# Sample_mean: 200.35

# %%
Name = {"Abidoye":45, "Aanuoluwapo":76, "Samuel":43}
index = ["Holuwagbotemi", "Aanuoluwapo"]
columns = ["exousia", "Asa"]
df = pd.DataFrame(data=Name, index=index)

# %%
df
# Out:
#                Abidoye  Aanuoluwapo  Samuel
# Holuwagbotemi       45           76      43
# Aanuoluwapo         45           76      43

# %%
Name = [[39, "portugal", 44], [36, "Argentina", 45], [33, "brazil",39]]
name = ["Christiano-Ronaldo", "lionel-Messi", "Neymar"]
career = ["age", "club", "trophy"]

df = pd.DataFrame(data=Name, index= name, columns = career)

# %%
df
# Out:
#                     age       club  trophy
# Christiano-Ronaldo   39   portugal      44
# lionel-Messi         36  Argentina      45
# Neymar               33     brazil      39

# %%
NAME = {"Age":[34, 56, 67], "name":["Ronaldo", "pele", "maradona"],"club":["Real madrid", "Barcelona", "paris german"]}
INDEX = [1, 2, 5]

df = pd.DataFrame(data=NAME, index=INDEX)

# %%
df
# Out:
#    Age      name          club
# 1   34   Ronaldo   Real madrid
# 2   56      pele     Barcelona
# 5   67  maradona  paris german

# %%
population_area
# Out:
# 200.35

# %%
population_area = df["Species_count"].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Species_count'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 population_area = df["Species_count"].mean()
#
# ...

# %%
population_area
# Out:
# 200.35

# %%
population_variance = df["Species_count"].var(ddof=1)
print("the total population_variance:", population_variance)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Species_count'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 population_variance = df["Species_count"].var(ddof=1)
# ...

# %%
population_variance = df["Species_count"].var(ddof=0)
print("this is the name of the total population:", population_variance)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Species_count'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[109], line 1
# ----> 1 population_variance = df["Species_count"].var(ddof=0)
# ...

# %%
x = np.array([["Adebisi", "iyiola","adesola"], ["akintayo","Adebayo", "Akinsayo"]])
index = ["name", "surname", ]
columns = ["first name", "last name", "middle name"]

df = pd.DataFrame(data=x, index=index, columns= columns)
df
# Out:
#         first name last name middle name
# name       Adebisi    iyiola     adesola
# surname   akintayo   Adebayo    Akinsayo

# %%
schools = {"university_of_ibadan":45, "university_of_lagos":34, "university_of_osun":33, "university_of_ilorin":33}
schools_index = ["school", "index"]
schools_columns = ["school", "estabilishment"]
department_schools_columns = pd.DataFrame(data = schools, index = schools_index)

# %%
department_schools_columns
# Out:
#         university_of_ibadan  university_of_lagos  university_of_osun  \
# school                    45                   34                  33
# index                     45                   34                  33
#
#         university_of_ilorin
# school                    33
# index                     33

# %%
schools = {"university_of_ibadan", "university_of_lagos","university_of_calabar"}

# %%
schools
# Out:
# {'university_of_calabar', 'university_of_ibadan', 'university_of_lagos'}

# %%
schools = list(schools)

# %%
schools
# Out:
# ['university_of_lagos', 'university_of_ibadan', 'university_of_calabar']

# %%
school = {"university_of_ilorin", "university_of_calabar", "university_of lagos"}
schoolss = school.union(schools)
schoolss
# Out:
# {'university_of lagos',
#  'university_of_calabar',
#  'university_of_ibadan',
#  'university_of_ilorin',
#  'university_of_lagos'}

# %%
schoolss = school.difference(schools)

# %%
schoolss
# Out:
# {'university_of lagos', 'university_of_ilorin'}

# %%
schoolss = school.intersection(schools)

# %%
schoolss
# Out:
# {'university_of_calabar'}

# %%
import matplotlib.pyplot as plt

# %%
schools = {"university_of_ibadan":56, "university_of_lagos":67, "university_of_Nigeria":34, "university_of_portharcourt":77, "university_of_Abuja":73}
school = schools.keys()
School = schools.values()
name_of_schools = np.arange(len(schools))
plt.bar(name_of_schools,School, alpha=0.3)
plt.xticks(name_of_schools, schools)
plt.ylabel(School)
plt.title("the name of the schools in western region of Nigeria")
plt.show()

# %%
school = schools.keys()
School = schools.values()
colors = ["RED", "YELLOW", "WHITE", "BROWN", "GREEN"]
plt.pie(School,labels=school,startangle=140)
plt.axis("equal")
plt.show()

# %%
atitude = {"positive":56, "negative":00, "pessimistic":22,"optimistic":78}
Atitude = atitude.keys()
Atitudes = atitude.values()
ALTITUDES = np.arange(len(atitude))

plt.bar(ALTITUDES, Atitudes, alpha=0.4)
plt.xticks(ALTITUDES, Atitude)
plt.ylabel(Atitudes)
plt.title("almost everyone in the world fall into this category")
plt.show()

# %%
Atitude= atitude.keys()
Atitudes = atitude.values()
colors = ["PINK", "BLACK", "BROWN", "WHITE"]
plt.pie(Atitudes, labels=Atitude, startangle =90)
plt.axis("equal")
plt.show()

# %%
Data = {"Region":["Amazon", "south asia", "east asia", "bougort"], "Destination_type":[234, 456, 745, 666], "population_type_year":[2000, 2450, 3450,7832]}
index_type = ["Region", "Destination_type_class", "population_type","Region_ground"]

df = pd.DataFrame(data=Data, index = index_type)

# %%
df
# Out:
#                             Region  Destination_type  population_type_year
# Region                      Amazon               234                  2000
# Destination_type_class  south asia               456                  2450
# population_type          east asia               745                  3450
# Region_ground              bougort               666                  7832

# %%
df.describe()
# Out:
#        Destination_type  population_type_year
# count          4.000000               4.00000
# mean         525.250000            3933.00000
# std          229.290754            2669.03653
# min          234.000000            2000.00000
# 25%          400.500000            2337.50000
# 50%          561.000000            2950.00000
# 75%          685.750000            4545.50000
# max          745.000000            7832.00000

# %%
df.head()
# Out:
#                             Region  Destination_type  population_type_year
# Region                      Amazon               234                  2000
# Destination_type_class  south asia               456                  2450
# population_type          east asia               745                  3450
# Region_ground              bougort               666                  7832

# %%
df.tail()
# Out:
#                             Region  Destination_type  population_type_year
# Region                      Amazon               234                  2000
# Destination_type_class  south asia               456                  2450
# population_type          east asia               745                  3450
# Region_ground              bougort               666                  7832

# %%
df.drop("Region", axis=0)
# Out:
#                             Region  Destination_type  population_type_year
# Destination_type_class  south asia               456                  2450
# population_type          east asia               745                  3450
# Region_ground              bougort               666                  7832

# %%
df.drop("Region", axis=1)
# Out:
#                         Destination_type  population_type_year
# Region                               234                  2000
# Destination_type_class               456                  2450
# population_type                      745                  3450
# Region_ground                        666                  7832

# %%
df["population_sample"] = df["population_type_year"] / df["Destination_type"]

# %%
df
# Out:
#                             Region  Destination_type  population_type_year  \
# Region                      Amazon               234                  2000
# Destination_type_class  south asia               456                  2450
# population_type          east asia               745                  3450
# Region_ground              bougort               666                  7832
#
#                         population_sample
# Region                           8.547009
# Destination_type_class           5.372807
# population_type                  4.630872
# Region_ground                   11.759760

# %%
df.sort_values("Region", ascending=False)
# Out:
#                             Region  Destination_type  population_type_year  \
# Destination_type_class  south asia               456                  2450
# population_type          east asia               745                  3450
# Region_ground              bougort               666                  7832
# Region                      Amazon               234                  2000
#
#                         population_sample
# Destination_type_class           5.372807
# population_type                  4.630872
# Region_ground                   11.759760
# Region                           8.547009

# %%
df.sort_values("Destination_type")
# Out:
#                             Region  Destination_type  population_type_year  \
# Region                      Amazon               234                  2000
# Destination_type_class  south asia               456                  2450
# Region_ground              bougort               666                  7832
# population_type          east asia               745                  3450
#
#                         population_sample
# Region                           8.547009
# Destination_type_class           5.372807
# Region_ground                   11.759760
# population_type                  4.630872

# %%
df.sort_values("Destination_type", ascending=False)
# Out:
#                             Region  Destination_type  population_type_year  \
# population_type          east asia               745                  3450
# Region_ground              bougort               666                  7832
# Destination_type_class  south asia               456                  2450
# Region                      Amazon               234                  2000
#
#                         population_sample
# population_type                  4.630872
# Region_ground                   11.759760
# Destination_type_class           5.372807
# Region                           8.547009

# %%
df.groupby("Destination_type")[["population_sample","population_type_year"]].mean()
# Out:
#                   population_sample  population_type_year
# Destination_type
# 234                        8.547009                2000.0
# 456                        5.372807                2450.0
# 666                       11.759760                7832.0
# 745                        4.630872                3450.0

# %%
df["population_language"] = np.mean(df["population_type_year"]).mean()

# %%
df["population_language"]
# Out:
# Region                    3933.0
# Destination_type_class    3933.0
# population_type           3933.0
# Region_ground             3933.0
# Name: population_language, dtype: float64

# %%
df["population_statistics"] = np.mean(df["population_sample"]).mean()

# %%
df["population_statistics"]
# Out:
# Region                    7.577612
# Destination_type_class    7.577612
# population_type           7.577612
# Region_ground             7.577612
# Name: population_statistics, dtype: float64

# %%
## software testing
# verification
# validation

# %%
def add(x,y):
    return x*y
    result = add(5,6)
    print("the intermediate second between the x and y is correct: {result}")

# %%
def number(x):
    """ the numbers that accept integer between 1 and 100 are given below, can you figure those integers out from this sphere"""
    if x > 1 or x < 100:
        print("the name of x is not equivalent to 1")
    else:
        print("the equivalent of x is 100")

# %%
z = -50

range_checker(z)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[191], line 3
#       1 z = -50
# ----> 3 range_checker(z)
#
# NameError: name 'range_checker' is not defined

# %%
z = 0
y = 50
if z < y:
    print("this factorial factor is equivalent")
else:
    print("this factorial factor is not equivalent")
# Out:
# this factorial factor is equivalent

# %%
a = 0
b = 30

def decision(a,b):
    if a < 25:
        print("the total number of value")
    else:
        print("no error in the value")
        if b < 25:
            print("the number is equivalent to thirty")
        else:
            print("no error in b")

decision(a,b)
# Out:
# the total number of value

# %%
y = 7
x = y*y*2
z = x +5 
print(F'equal Z :{z}')
# Out:
# equal Z :103

# %%
x = 45
y = y*y*4
x = y + 4
print(f'equal X:{x}')
# Out:
# equal X:200

# %%
v = 67
x = y*y*2
z = x -8
print(f'equal Z:{z}')
# Out:
# equal Z:76824
