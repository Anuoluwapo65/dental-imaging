# %% [markdown]
# ## DATA VISUALISATION

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = {"Biochemistry":71, "physiology": 72, "Anatomy":70, "pathology":70, "pharmacology":71,"oral medicine":77, "oral radiology":77, "oral pathology":75,"oraloncology":74}

# %%
y = x.values()

# %%
z = x.keys()

# %%
A = np.arange(len(x))

# %%
plt.bar(A, z, alpha=0.5)
plt.xticks(A, z)
plt.ylabel(y)
plt.title("MY ACADEMICS LONG TERM GOAL")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
